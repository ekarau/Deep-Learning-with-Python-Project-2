# %% [markdown]
# # Baseline 3D U-Net
#
# **Owner:** Ege Karaurgan (229910141)
#
# The baseline is the strongest completed operating point: fold 0, seed 42, best validation mean Dice = **0.8576**.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

results = pd.read_csv(PROJECT_ROOT / 'ablation' / 'results' / 'all_runs.csv')
results[results['scenario'].eq('baseline_3d_unet')]

# %% [markdown]
# Training command used in Colab:
#
# ```bash
# python -m src.training.train --config configs/baseline.yaml --fold 0 --data-root data/training
# ```
