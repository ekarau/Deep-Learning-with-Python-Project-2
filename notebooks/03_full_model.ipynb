# %% [markdown]
# # Full Model and Autoencoder/VAE Components
#
# **Owner:** Mehmet Emin Akkaya (2309011036)
#
# This notebook records the two-stage design: denoising autoencoder pretraining followed by segmentation and VAE diagnosis fine-tuning.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

results = pd.read_csv(PROJECT_ROOT / 'ablation' / 'results' / 'all_runs.csv')
results[results['scenario'].isin(['full_model', 'ablation_A2_no_pretraining', 'ablation_A4_no_vae'])]

# %% [markdown]
# Key finding: removing autoencoder pretraining raises Dice from 0.7412 to 0.8555, indicating objective mismatch between reconstruction and segmentation.
