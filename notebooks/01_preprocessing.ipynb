# %% [markdown]
# # Preprocessing Pipeline
#
# **Owner:** Selvinaz Sayın (220901755)
#
# This notebook documents the intended MONAI preprocessing flow: spacing normalisation, fixed-size cropping/padding, non-zero voxel z-score normalisation, and training-time augmentation.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

PROJECT_ROOT

# %%
from src.data.transforms import build_train_transforms, build_val_transforms

spacing = (1.25, 1.25, 10.0)
spatial_size = (16, 224, 224)
train_tx = build_train_transforms(spacing=spacing, spatial_size=spatial_size)
val_tx = build_val_transforms(spacing=spacing, spatial_size=spatial_size)

train_tx, val_tx
